# %% [markdown]
# # pycaret

# %% [markdown]
# ## Classification

# %%
# !pip install --pre pycaret

# %%
from pycaret.datasets import get_data
data = get_data('juice')
# Out:
#    Id Purchase  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 0   1       CH             237        1     1.75     1.99    0.00     0.0
# 1   2       CH             239        1     1.75     1.99    0.00     0.3
# 2   3       CH             245        1     1.86     2.09    0.17     0.0
# 3   4       MM             227        1     1.69     1.69    0.00     0.0
# 4   5       CH             228        7     1.69     1.69    0.00     0.0
#
#    SpecialCH  SpecialMM   LoyalCH  SalePriceMM  SalePriceCH  PriceDiff Store7  \
# 0          0          0  0.500000         1.99         1.75       0.24     No
# 1          0          1  0.600000         1.69         1.75      -0.06     No
# 2          0          0  0.680000         2.09         1.69       0.40     No
# 3          0          0  0.400000         1.69         1.69       0.00     No
# 4          0          0  0.956535         1.69         1.69       0.00    Yes
#
#    PctDiscMM  PctDiscCH  ListPriceDiff  STORE
# 0   0.000000   0.000000           0.24      1
# 1   0.150754   0.000000           0.24      1
# 2   0.000000   0.091398           0.23      1
# 3   0.000000   0.000000           0.00      1
# 4   0.000000   0.000000           0.00      0

# %%
from pycaret.classification import *
s = setup(data, target = 'Purchase')
# Out:
# <style type="text/css">
# #T_0dd80_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0dd80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0dd80_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0dd80_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0dd80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0dd80_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0dd80_row0_col1" class="data row0 col1" >7165</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0dd80_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0dd80_row1_col1" class="data row1 col1" >Purchase</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0dd80_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0dd80_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0dd80_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_0dd80_row3_col1" class="data row3 col1" >CH: 0, MM: 1</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0dd80_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_0dd80_row4_col1" class="data row4 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0dd80_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_0dd80_row5_col1" class="data row5 col1" >(1070, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0dd80_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_0dd80_row6_col1" class="data row6 col1" >(749, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0dd80_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_0dd80_row7_col1" class="data row7 col1" >(321, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0dd80_row8_col0" class="data row8 col0" >Ordinal features</td>
#       <td id="T_0dd80_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0dd80_row9_col0" class="data row9 col0" >Numeric features</td>
#       <td id="T_0dd80_row9_col1" class="data row9 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0dd80_row10_col0" class="data row10 col0" >Categorical features</td>
#       <td id="T_0dd80_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0dd80_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_0dd80_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0dd80_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_0dd80_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0dd80_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_0dd80_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0dd80_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_0dd80_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0dd80_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_0dd80_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0dd80_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_0dd80_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0dd80_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_0dd80_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0dd80_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_0dd80_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0dd80_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_0dd80_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0dd80_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_0dd80_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0dd80_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_0dd80_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_0dd80_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_0dd80_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0dd80_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_0dd80_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_0dd80_row23_col1" class="data row23 col1" >eef8</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_924d1 th {
#   text-align: left;
# }
# #T_924d1_row0_col0, #T_924d1_row0_col2, #T_924d1_row0_col3, #T_924d1_row0_col4, #T_924d1_row1_col0, #T_924d1_row1_col1, #T_924d1_row1_col3, #T_924d1_row1_col4, #T_924d1_row1_col5, #T_924d1_row1_col6, #T_924d1_row1_col7, #T_924d1_row2_col0, #T_924d1_row2_col1, #T_924d1_row2_col2, #T_924d1_row2_col3, #T_924d1_row2_col4, #T_924d1_row2_col5, #T_924d1_row2_col6, #T_924d1_row2_col7, #T_924d1_row3_col0, #T_924d1_row3_col1, #T_924d1_row3_col2, #T_924d1_row3_col3, #T_924d1_row3_col5, #T_924d1_row3_col6, #T_924d1_row3_col7, #T_924d1_row4_col0, #T_924d1_row4_col1, #T_924d1_row4_col2, #T_924d1_row4_col3, #T_924d1_row4_col4, #T_924d1_row4_col5, #T_924d1_row4_col6, #T_924d1_row4_col7, #T_924d1_row5_col0, #T_924d1_row5_col1, #T_924d1_row5_col2, #T_924d1_row5_col3, #T_924d1_row5_col4, #T_924d1_row5_col5, #T_924d1_row5_col6, #T_924d1_row5_col7, #T_924d1_row6_col0, #T_924d1_row6_col1, #T_924d1_row6_col2, #T_924d1_row6_col3, #T_924d1_row6_col4, #T_924d1_row6_col5, #T_924d1_row6_col6, #T_924d1_row6_col7, #T_924d1_row7_col0, #T_924d1_row7_col1, #T_924d1_row7_col2, #T_924d1_row7_col3, #T_924d1_row7_col4, #T_924d1_row7_col5, #T_924d1_row7_col6, #T_924d1_row7_col7, #T_924d1_row8_col0, #T_924d1_row8_col1, #T_924d1_row8_col2, #T_924d1_row8_col3, #T_924d1_row8_col4, #T_924d1_row8_col5, #T_924d1_row8_col6, #T_924d1_row8_col7, #T_924d1_row9_col0, #T_924d1_row9_col1, #T_924d1_row9_col2, #T_924d1_row9_col3, #T_924d1_row9_col4, #T_924d1_row9_col5, #T_924d1_row9_col6, #T_924d1_row9_col7, #T_924d1_row10_col0, #T_924d1_row10_col1, #T_924d1_row10_col2, #T_924d1_row10_col4, #T_924d1_row10_col5, #T_924d1_row10_col6, #T_924d1_row10_col7, #T_924d1_row11_col0, #T_924d1_row11_col1, #T_924d1_row11_col2, #T_924d1_row11_col3, #T_924d1_row11_col4, #T_924d1_row11_col5, #T_924d1_row11_col6, #T_924d1_row11_col7, #T_924d1_row12_col0, #T_924d1_row12_col1, #T_924d1_row12_col2, #T_924d1_row12_col3, #T_924d1_row12_col4, #T_924d1_row12_col5, #T_924d1_row12_col6, #T_924d1_row12_col7, #T_924d1_row13_col0, #T_924d1_row13_col1, #T_924d1_row13_col2, #T_924d1_row13_col3, #T_924d1_row13_col4, #T_924d1_row13_col5, #T_924d1_row13_col6, #T_924d1_row13_col7 {
#   text-align: left;
# }
# #T_924d1_row0_col1, #T_924d1_row0_col5, #T_924d1_row0_col6, #T_924d1_row0_col7, #T_924d1_row1_col2, #T_924d1_row3_col4, #T_924d1_row10_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_924d1_row0_col8, #T_924d1_row1_col8, #T_924d1_row3_col8, #T_924d1_row4_col8, #T_924d1_row5_col8, #T_924d1_row6_col8, #T_924d1_row7_col8, #T_924d1_row8_col8, #T_924d1_row9_col8, #T_924d1_row10_col8, #T_924d1_row11_col8, #T_924d1_row12_col8, #T_924d1_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_924d1_row2_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_924d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_924d1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_924d1_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_924d1_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_924d1_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_924d1_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_924d1_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_924d1_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_924d1_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_924d1_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_924d1_level0_row0" class="row_heading level0 row0" >lda</th>
#       <td id="T_924d1_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_924d1_row0_col1" class="data row0 col1" >0.8211</td>
#       <td id="T_924d1_row0_col2" class="data row0 col2" >0.8833</td>
#       <td id="T_924d1_row0_col3" class="data row0 col3" >0.7495</td>
#       <td id="T_924d1_row0_col4" class="data row0 col4" >0.7851</td>
#       <td id="T_924d1_row0_col5" class="data row0 col5" >0.7645</td>
#       <td id="T_924d1_row0_col6" class="data row0 col6" >0.6206</td>
#       <td id="T_924d1_row0_col7" class="data row0 col7" >0.6232</td>
#       <td id="T_924d1_row0_col8" class="data row0 col8" >0.0090</td>
#     </tr>
#     <tr>
#       <th id="T_924d1_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_924d1_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_924d1_row1_col1" class="data row1 col1" >0.8197</td>
#       <td id="T_924d1_row1_col2" class="data row1 col2" >0.8892</td>
#       <td id="T_924d1_row1_col3" class="data row1 col3" >0.7497</td>
#       <td id="T_924d1_row1_col4" class="data row1 col4" >0.7830</td>
#       <td id="T_924d1_row1_col5" class="data row1 col5" >0.7633</td>
#       <td id="T_924d1_row1_col6" class="data row1 col6" >0.6180</td>
#       <td id="T_924d1_row1_col7" class="data row1 col7" >0.6210</td>
#       <td id="T_924d1_row1_col8" class="data row1 col8" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_924d1_level0_row2" class="row_heading level0 row2" >ridge</th>
#       <td id="T_924d1_row2_col0" class="data row2 col0" >Ridge Classifier</td>
#       <td id="T_924d1_row2_col1" class="data row2 col1" >0.8171</td>
#       <td id="T_924d1_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_924d1_row2_col3" class="data row2 col3" >0.7360</td>
#       <td id="T_924d1_row2_col4" class="data row2 col4" >0.7856</td>
#       <td id="T_924d1_row2_col5" class="data row2 col5" >0.7576</td>
#       <td id="T_924d1_row2_col6" class="data row2 col6" >0.6112</td>
#       <td id="T_924d1_row2_col7" class="data row2 col7" >0.6141</td>
#       <td id="T_924d1_row2_col8" class="data row2 col8" >0.0070</td>
#     </tr>
#     <tr>
#       <th id="T_924d1_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_924d1_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_924d1_row3_col1" class="data row3 col1" >0.8117</td>
#       <td id="T_924d1_row3_col2" class="data row3 col2" >0.8831</td>
#       <td id="T_924d1_row3_col3" class="data row3 col3" >0.7121</td>
#       <td id="T_924d1_row3_col4" class="data row3 col4" >0.7881</td>
#       <td id="T_924d1_row3_col5" class="data row3 col5" >0.7462</td>
#       <td id="T_924d1_row3_col6" class="data row3 col6" >0.5974</td>
#       <td id="T_924d1_row3_col7" class="data row3 col7" >0.6010</td>
#       <td id="T_924d1_row3_col8" class="data row3 col8" >0.3470</td>
#     </tr>
#     <tr>
#       <th id="T_924d1_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_924d1_row4_col0" class="data row4 col0" >Random Forest Classifier</td>
#       <td id="T_924d1_row4_col1" class="data row4 col1" >0.8024</td>
#       <td id="T_924d1_row4_col2" class="data row4 col2" >0.8684</td>
#       <td id="T_924d1_row4_col3" class="data row4 col3" >0.7324</td>
#       <td id="T_924d1_row4_col4" class="data row4 col4" >0.7576</td>
#       <td id="T_924d1_row4_col5" class="data row4 col5" >0.7424</td>
#       <td id="T_924d1_row4_col6" class="data row4 col6" >0.5824</td>
#       <td id="T_924d1_row4_col7" class="data row4 col7" >0.5849</td>
#       <td id="T_924d1_row4_col8" class="data row4 col8" >0.0490</td>
#     </tr>
#     <tr>
#       <th id="T_924d1_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_924d1_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_924d1_row5_col1" class="data row5 col1" >0.7970</td>
#       <td id="T_924d1_row5_col2" class="data row5 col2" >0.8617</td>
#       <td id="T_924d1_row5_col3" class="data row5 col3" >0.6877</td>
#       <td id="T_924d1_row5_col4" class="data row5 col4" >0.7678</td>
#       <td id="T_924d1_row5_col5" class="data row5 col5" >0.7226</td>
#       <td id="T_924d1_row5_col6" class="data row5 col6" >0.5639</td>
#       <td id="T_924d1_row5_col7" class="data row5 col7" >0.5684</td>
#       <td id="T_9
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
plot_model(best)

# %%
print(best)
# Out:
# LinearDiscriminantAnalysis(covariance_estimator=None, n_components=None,
#                            priors=None, shrinkage=None, solver='svd',
#                            store_covariance=False, tol=0.0001)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best, plot = 'auc')

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_18011">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18011_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_18011_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_18011_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_18011_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_18011_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_18011_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_18011_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_18011_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18011_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18011_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_18011_row0_col1" class="data row0 col1" >0.8505</td>
#       <td id="T_18011_row0_col2" class="data row0 col2" >0.9204</td>
#       <td id="T_18011_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_18011_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_18011_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_18011_row0_col6" class="data row0 col6" >0.6809</td>
#       <td id="T_18011_row0_col7" class="data row0 col7" >0.6824</td>
#     </tr>
#   </tbody>
# </table>
#         Id  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  \
# 749   1029             263        7     1.86     2.13    0.27    0.00
# 750    762             278        3     2.09     2.09    0.20    0.00
# 751    425             242        3     1.99     2.23    0.00    0.00
# 752    494             246        3     1.99     2.23    0.00    0.00
# 753    701             247        3     1.99     2.23    0.00    0.00
# ...    ...             ...      ...      ...      ...     ...     ...
# 1065   408             236        1     1.75     1.99    0.00    0.00
# 1066   127             266        1     1.86     1.99    0.00    0.10
# 1067   948             260        3     1.99     2.09    0.00    0.00
# 1068   387             229        2     1.69     1.69    0.00    0.00
# 1069   988             274        7     1.86     2.13    0.47    0.54
#
#       SpecialCH  SpecialMM   LoyalCH  ...  SalePriceCH  PriceDiff  Store7  \
# 749           0          0  0.852695  ...         1.59       0.54     Yes
# 750           0          0  0.561472  ...         1.89       0.20      No
# 751           0          0  0.416000  ...         1.99       0.24      No
# 752           0          0  0.500000  ...         1.99       0.24      No
# 753           0          0  0.003689  ...         1.99       0.24      No
# ...         ...        ...       ...  ...          ...        ...     ...
# 1065          0          0  0.346778  ...         1.75       0.24      No
# 1066          0          0  0.829332  ...         1.86       0.03      No
# 1067          0          0  0.011649  ...         1.99       0.10      No
# 1068          0          0  0.165373  ...         1.69       0.00      No
# 1069          1          0  0.592251  ...         1.39       0.20     Yes
#
#      PctDiscMM  PctDiscCH  ListPriceDiff  STORE  Purchase prediction_label  \
# 749   0.000000   0.145161           0.27      0        CH               CH
# 750   0.000000   0.095694           0.00      3        CH               CH
# 751   0.000000   0.000000           0.24      3        CH               MM
# 752   0.000000   0.000000           0.24      3        CH               CH
# 753   0.000000   0.000000           0.24      3        MM               MM
# ...        ...        ...            ...    ...       ...              ...
# 1065  0.000000   0.000000           0.24      1        MM               MM
# 1066  0.050251   0.000000           0.13      1        CH               CH
# 1067  0.000000   0.000000           0.10      3        MM               MM
# 1068  0.000000   0.000000           0.00      2        MM               MM
# 1069  0.253521   0.252688           0.27      0        CH               CH
#
#      prediction_score
# 749            0.9857
# 750            0.7055
# 751            0.5017
# 752            0.6469
# 753            0.9478
# ...               ...
# 1065           0.6944
# 1066           0.9207
# 1067           0.9630
# 1068           0.9545
# 1069           0.8310
#
# [321 rows x 21 columns]

# %%
predictions = predict_model(best, data=data)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e777">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e777_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5e777_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_5e777_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_5e777_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_5e777_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_5e777_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_5e777_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_5e777_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e777_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e777_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_5e777_row0_col1" class="data row0 col1" >0.8327</td>
#       <td id="T_5e777_row0_col2" class="data row0 col2" >0.9020</td>
#       <td id="T_5e777_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5e777_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5e777_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_5e777_row0_col6" class="data row0 col6" >0.6448</td>
#       <td id="T_5e777_row0_col7" class="data row0 col7" >0.6454</td>
#     </tr>
#   </tbody>
# </table>
#    Id  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  SpecialCH  \
# 0   1             237        1     1.75     1.99    0.00     0.0          0
# 1   2             239        1     1.75     1.99    0.00     0.3          0
# 2   3             245        1     1.86     2.09    0.17     0.0          0
# 3   4             227        1     1.69     1.69    0.00     0.0          0
# 4   5             228        7     1.69     1.69    0.00     0.0          0
#
#    SpecialMM   LoyalCH  ...  SalePriceCH  PriceDiff  Store7 PctDiscMM  \
# 0          0  0.500000  ...         1.75       0.24      No  0.000000
# 1          1  0.600000  ...         1.75      -0.06      No  0.150754
# 2          0  0.680000  ...         1.69       0.40      No  0.000000
# 3          0  0.400000  ...         1.69       0.00      No  0.000000
# 4          0  0.956535  ...         1.69       0.00     Yes  0.000000
#
#    PctDiscCH  ListPriceDiff  STORE  Purchase prediction_label prediction_score
# 0   0.000000           0.24      1        CH               CH           0.5657
# 1   0.000000           0.24      1        CH               CH           0.5521
# 2   0.091398           0.23      1        CH               CH           0.8879
# 3   0.000000           0.00      1        MM               MM           0.7996
# 4   0.000000           0.00      0        CH               CH           0.9547
#
# [5 rows x 21 columns]

# %%
predictions = predict_model(best, data=data, raw_score=True)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_ec722">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec722_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ec722_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ec722_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ec722_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ec722_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ec722_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ec722_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ec722_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec722_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec722_row0_col0" class="data row0 col0" >Linear Discriminant Analysis</td>
#       <td id="T_ec722_row0_col1" class="data row0 col1" >0.8327</td>
#       <td id="T_ec722_row0_col2" class="data row0 col2" >0.9020</td>
#       <td id="T_ec722_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ec722_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ec722_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_ec722_row0_col6" class="data row0 col6" >0.6448</td>
#       <td id="T_ec722_row0_col7" class="data row0 col7" >0.6454</td>
#     </tr>
#   </tbody>
# </table>
#    Id  WeekofPurchase  StoreID  PriceCH  PriceMM  DiscCH  DiscMM  SpecialCH  \
# 0   1             237        1     1.75     1.99    0.00     0.0          0
# 1   2             239        1     1.75     1.99    0.00     0.3          0
# 2   3             245        1     1.86     2.09    0.17     0.0          0
# 3   4             227        1     1.69     1.69    0.00     0.0          0
# 4   5             228        7     1.69     1.69    0.00     0.0          0
#
#    SpecialMM   LoyalCH  ...  PriceDiff  Store7  PctDiscMM PctDiscCH  \
# 0          0  0.500000  ...       0.24      No   0.000000  0.000000
# 1          1  0.600000  ...      -0.06      No   0.150754  0.000000
# 2          0  0.680000  ...       0.40      No   0.000000  0.091398
# 3          0  0.400000  ...       0.00      No   0.000000  0.000000
# 4          0  0.956535  ...       0.00     Yes   0.000000  0.000000
#
#    ListPriceDiff  STORE  Purchase  prediction_label prediction_score_CH  \
# 0           0.24      1        CH                CH              0.5657
# 1           0.24      1        CH                CH              0.5521
# 2           0.23      1        CH                CH              0.8879
# 3           0.00      1        MM                MM              0.2004
# 4           0.00      0        CH                CH              0.9547
#
#   prediction_score_MM
# 0              0.4343
# 1              0.4479
# 2              0.1121
# 3              0.7996
# 4              0.0453
#
# [5 rows x 22 columns]

# %%
save_model(best, 'my_best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=/var/folders/jx/rdhgw4n94cvb3tl_p0k9_4br0000gn/T/joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Id', 'WeekofPurchase', 'StoreID',
#                                               'PriceCH', 'PriceMM', 'DiscCH',
#                                               'DiscMM', 'SpecialCH', 'Specia...
#                                                                 drop_invariant=False,
#                                                                 handle_missing='return_nan',
#                                                                 handle_unknown='value',
#                                                                 mapping=[{'col': 'Store7',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': No     0
#  Yes    1
#  NaN   -1
#  dtype: int64}],
#                                                                 return_df=True,
#                                                                 verbose=0))),
#                  ('trained_model',
#                   LinearDiscriminantAnalysis(covariance_estimator=None,
#                                              n_components=None, priors=None,
#                                              shrinkage=None, solver='svd',
#                                              store_covariance=False,
#                                              tol=0.0001))],
#           verbose=False),
#  'my_best_pipeline.pkl')

# %%
# load model
loaded_model = load_model('my_best_pipeline')
print(loaded_model)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=Memory(location=/var/folders/jx/rdhgw4n94cvb3tl_p0k9_4br0000gn/T/joblib),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['Id', 'WeekofPurchase', 'StoreID',
#                                              'PriceCH', 'PriceMM', 'DiscCH',
#                                              'DiscMM', 'SpecialCH', 'Specia...
#                                                                drop_invariant=False,
#                                                                handle_missing='return_nan',
#                                                                handle_unknown='value',
#                                                                mapping=[{'col': 'Store7',
#                                                                          'data_type': dtype('O'),
#                                                                          'mapping': No     0
# Yes    1
# NaN   -1
# dtype: int64}],
#                                                                return_df=True,
#                                                                verbose=0))),
#                 ('trained_model',
#                  LinearDiscriminantAnalysis(covariance_estimator=None,
#                                             n_components=None, priors=None,
#                                             shrinkage=None, solver='svd',
#                                             store_covariance=False,
#                                             tol=0.0001))],
#          verbose=False)

# %% [markdown]
# ## Regression

# %%
from pycaret.datasets import get_data
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pycaret.regression import *
s = setup(data, target = 'charges')
# Out:
# <style type="text/css">
# #T_83e16_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_83e16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83e16_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_83e16_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83e16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83e16_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_83e16_row0_col1" class="data row0 col1" >6479</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83e16_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_83e16_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83e16_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_83e16_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_83e16_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_83e16_row3_col1" class="data row3 col1" >(1338, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_83e16_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_83e16_row4_col1" class="data row4 col1" >(1338, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_83e16_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_83e16_row5_col1" class="data row5 col1" >(936, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_83e16_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_83e16_row6_col1" class="data row6 col1" >(402, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_83e16_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_83e16_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_83e16_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_83e16_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_83e16_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_83e16_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_83e16_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_83e16_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_83e16_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_83e16_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_83e16_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_83e16_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_83e16_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_83e16_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_83e16_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_83e16_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_83e16_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_83e16_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_83e16_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_83e16_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_83e16_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_83e16_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_83e16_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_83e16_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_83e16_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_83e16_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_83e16_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_83e16_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_83e16_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_83e16_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_83e16_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_83e16_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_83e16_row22_col1" class="data row22 col1" >e9fd</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_34f6c th {
#   text-align: left;
# }
# #T_34f6c_row0_col0, #T_34f6c_row0_col6, #T_34f6c_row1_col0, #T_34f6c_row1_col1, #T_34f6c_row1_col2, #T_34f6c_row1_col3, #T_34f6c_row1_col4, #T_34f6c_row1_col5, #T_34f6c_row1_col6, #T_34f6c_row2_col0, #T_34f6c_row2_col1, #T_34f6c_row2_col2, #T_34f6c_row2_col3, #T_34f6c_row2_col4, #T_34f6c_row2_col5, #T_34f6c_row2_col6, #T_34f6c_row3_col0, #T_34f6c_row3_col1, #T_34f6c_row3_col2, #T_34f6c_row3_col3, #T_34f6c_row3_col4, #T_34f6c_row3_col5, #T_34f6c_row3_col6, #T_34f6c_row4_col0, #T_34f6c_row4_col1, #T_34f6c_row4_col2, #T_34f6c_row4_col3, #T_34f6c_row4_col4, #T_34f6c_row4_col5, #T_34f6c_row4_col6, #T_34f6c_row5_col0, #T_34f6c_row5_col1, #T_34f6c_row5_col2, #T_34f6c_row5_col3, #T_34f6c_row5_col4, #T_34f6c_row5_col5, #T_34f6c_row5_col6, #T_34f6c_row6_col0, #T_34f6c_row6_col1, #T_34f6c_row6_col2, #T_34f6c_row6_col3, #T_34f6c_row6_col4, #T_34f6c_row6_col5, #T_34f6c_row6_col6, #T_34f6c_row7_col0, #T_34f6c_row7_col1, #T_34f6c_row7_col2, #T_34f6c_row7_col3, #T_34f6c_row7_col4, #T_34f6c_row7_col5, #T_34f6c_row7_col6, #T_34f6c_row8_col0, #T_34f6c_row8_col1, #T_34f6c_row8_col2, #T_34f6c_row8_col3, #T_34f6c_row8_col4, #T_34f6c_row8_col5, #T_34f6c_row8_col6, #T_34f6c_row9_col0, #T_34f6c_row9_col1, #T_34f6c_row9_col2, #T_34f6c_row9_col3, #T_34f6c_row9_col4, #T_34f6c_row9_col5, #T_34f6c_row9_col6, #T_34f6c_row10_col0, #T_34f6c_row10_col1, #T_34f6c_row10_col2, #T_34f6c_row10_col3, #T_34f6c_row10_col4, #T_34f6c_row10_col5, #T_34f6c_row10_col6, #T_34f6c_row11_col0, #T_34f6c_row11_col1, #T_34f6c_row11_col2, #T_34f6c_row11_col3, #T_34f6c_row11_col4, #T_34f6c_row11_col5, #T_34f6c_row11_col6, #T_34f6c_row12_col0, #T_34f6c_row12_col1, #T_34f6c_row12_col2, #T_34f6c_row12_col3, #T_34f6c_row12_col4, #T_34f6c_row12_col5, #T_34f6c_row13_col0, #T_34f6c_row13_col1, #T_34f6c_row13_col2, #T_34f6c_row13_col3, #T_34f6c_row13_col4, #T_34f6c_row13_col5, #T_34f6c_row13_col6, #T_34f6c_row14_col0, #T_34f6c_row14_col1, #T_34f6c_row14_col2, #T_34f6c_row14_col3, #T_34f6c_row14_col4, #T_34f6c_row14_col5, #T_34f6c_row14_col6, #T_34f6c_row15_col0, #T_34f6c_row15_col1, #T_34f6c_row15_col2, #T_34f6c_row15_col3, #T_34f6c_row15_col4, #T_34f6c_row15_col5, #T_34f6c_row15_col6, #T_34f6c_row16_col0, #T_34f6c_row16_col1, #T_34f6c_row16_col2, #T_34f6c_row16_col3, #T_34f6c_row16_col4, #T_34f6c_row16_col5, #T_34f6c_row16_col6, #T_34f6c_row17_col0, #T_34f6c_row17_col1, #T_34f6c_row17_col2, #T_34f6c_row17_col3, #T_34f6c_row17_col4, #T_34f6c_row17_col5, #T_34f6c_row17_col6 {
#   text-align: left;
# }
# #T_34f6c_row0_col1, #T_34f6c_row0_col2, #T_34f6c_row0_col3, #T_34f6c_row0_col4, #T_34f6c_row0_col5, #T_34f6c_row12_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_34f6c_row0_col7, #T_34f6c_row1_col7, #T_34f6c_row2_col7, #T_34f6c_row3_col7, #T_34f6c_row4_col7, #T_34f6c_row5_col7, #T_34f6c_row6_col7, #T_34f6c_row7_col7, #T_34f6c_row8_col7, #T_34f6c_row9_col7, #T_34f6c_row10_col7, #T_34f6c_row11_col7, #T_34f6c_row12_col7, #T_34f6c_row13_col7, #T_34f6c_row14_col7, #T_34f6c_row15_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_34f6c_row16_col7, #T_34f6c_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_34f6c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34f6c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_34f6c_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_34f6c_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_34f6c_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_34f6c_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_34f6c_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_34f6c_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_34f6c_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34f6c_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_34f6c_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_34f6c_row0_col1" class="data row0 col1" >2340.0451</td>
#       <td id="T_34f6c_row0_col2" class="data row0 col2" >18437391.9555</td>
#       <td id="T_34f6c_row0_col3" class="data row0 col3" >4253.4559</td>
#       <td id="T_34f6c_row0_col4" class="data row0 col4" >0.8729</td>
#       <td id="T_34f6c_row0_col5" class="data row0 col5" >0.3825</td>
#       <td id="T_34f6c_row0_col6" class="data row0 col6" >0.2519</td>
#       <td id="T_34f6c_row0_col7" class="data row0 col7" >0.0230</td>
#     </tr>
#     <tr>
#       <th id="T_34f6c_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_34f6c_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_34f6c_row1_col1" class="data row1 col1" >2576.5932</td>
#       <td id="T_34f6c_row1_col2" class="data row1 col2" >20240875.2613</td>
#       <td id="T_34f6c_row1_col3" class="data row1 col3" >4462.3994</td>
#       <td id="T_34f6c_row1_col4" class="data row1 col4" >0.8610</td>
#       <td id="T_34f6c_row1_col5" class="data row1 col5" >0.4708</td>
#       <td id="T_34f6c_row1_col6" class="data row1 col6" >0.3041</td>
#       <td id="T_34f6c_row1_col7" class="data row1 col7" >0.0160</td>
#     </tr>
#     <tr>
#       <th id="T_34f6c_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_34f6c_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_34f6c_row2_col1" class="data row2 col1" >2521.1213</td>
#       <td id="T_34f6c_row2_col2" class="data row2 col2" >21039687.2585</td>
#       <td id="T_34f6c_row2_col3" class="data row2 col3" >4553.1233</td>
#       <td id="T_34f6c_row2_col4" class="data row2 col4" >0.8546</td>
#       <td id="T_34f6c_row2_col5" class="data row2 col5" >0.4359</td>
#       <td id="T_34f6c_row2_col6" class="data row2 col6" >0.2938</td>
#       <td id="T_34f6c_row2_col7" class="data row2 col7" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_34f6c_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_34f6c_row3_col0" class="data row3 col0" >AdaBoost Regressor</td>
#       <td id="T_34f6c_row3_col1" class="data row3 col1" >3515.6152</td>
#       <td id="T_34f6c_row3_col2" class="data row3 col2" >22651363.2468</td>
#       <td id="T_34f6c_row3_col3" class="data row3 col3" >4710.2911</td>
#       <td id="T_34f6c_row3_col4" class="data row3 col4" >0.8430</td>
#       <td id="T_34f6c_row3_col5" class="data row3 col5" >0.5298</td>
#       <td id="T_34f6c_row3_col6" class="data row3 col6" >0.5444</td>
#       <td id="T_34f6c_row3_col7" class="data row3 col7" >0.0110</td>
#     </tr>
#     <tr>
#       <th id="T_34f6c_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_34f6c_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_34f6c_row4_col1" class="data row4 col1" >2575.4441</td>
#       <td id="T_34f6c_row4_col2" class="data row4 col2" >23633043.8506</td>
#       <td id="T_34f6c_row4_col3" class="data row4 col3" >4830.2149</td>
#       <td id="T_34f6c_row4_col4" class="data row4 col4" >0.8357</td>
#       <td id="T_34f6c_row4_col5" class="data row4 col5" >0.4382</td>
#       <td id="T_34f6c_row4_col6" class="data row4 col6" >0.2916</td>
#       <td id="T_34f6c_row4_col7" class="data row4 col7" >0.0430</td>
#     </tr>
#     <tr>
#       <th id="T_34f6c_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_34f6c_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_34f6c_row5_col1" class="data row5 col1" >4125.1008</td>
#       <td id="T_34f6c_row5_col2" class="data row5 col2" >34388637.3943</td>
#       <td id="T_34f6c_row5_col3" class="data row5 col3" >5849.7099</td>
#       <td id="T_34f6c_row5_col4" class="data row5 col4" >0.7638</td>
#       <td id="T_34f6c_row5_col5" class="data row5 col5" >0.5864</td>
#       <td id="T_34f6c_row5_col6" class="data row5 col6" >0.4218</td>
#       <td id="T_34f6c_row5_col7" class="data
# Processing:   0%|          | 0/77 [00:00<?, ?it/s]

# %%
print(best)
# Out:
# GradientBoostingRegressor(random_state=6479)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best, plot = 'residuals')

# %%
plot_model(best, plot = 'feature')

# %%
predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0c9b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c9b1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0c9b1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0c9b1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0c9b1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0c9b1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0c9b1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0c9b1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c9b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c9b1_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_0c9b1_row0_col1" class="data row0 col1" >2691.9421</td>
#       <td id="T_0c9b1_row0_col2" class="data row0 col2" >26588810.4575</td>
#       <td id="T_0c9b1_row0_col3" class="data row0 col3" >5156.4339</td>
#       <td id="T_0c9b1_row0_col4" class="data row0 col4" >0.8150</td>
#       <td id="T_0c9b1_row0_col5" class="data row0 col5" >0.4610</td>
#       <td id="T_0c9b1_row0_col6" class="data row0 col6" >0.2908</td>
#     </tr>
#   </tbody>
# </table>
#       age     sex        bmi  children smoker     region       charges  \
# 936    31    male  27.645000         2     no  northeast   5031.269531
# 937    29    male  38.939999         1     no  southeast   3471.409668
# 938    42    male  35.799999         2     no  southwest   7160.094238
# 939    35  female  27.700001         3     no  southwest   6414.178223
# 940    43    male  34.959999         1    yes  northeast  41034.222656
# ...   ...     ...        ...       ...    ...        ...           ...
# 1333   55  female  30.500000         0     no  southwest  10704.469727
# 1334   27  female  21.469999         0     no  northwest   3353.470215
# 1335   44  female  25.000000         1     no  southwest   7623.518066
# 1336   40  female  27.400000         1     no  southwest   6496.886230
# 1337   23  female  42.750000         1    yes  northeast  40904.199219
#
#       prediction_label
# 936        6967.007058
# 937        6135.921114
# 938        7796.709445
# 939        8382.177532
# 940       40812.003935
# ...                ...
# 1333      11498.712852
# 1334       3422.085949
# 1335      10675.837600
# 1336       7372.509985
# 1337      40985.263821
#
# [402 rows x 8 columns]

# %%
predictions = predict_model(best, data=data)
predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_c9a80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9a80_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c9a80_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c9a80_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c9a80_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c9a80_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c9a80_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c9a80_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9a80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9a80_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_c9a80_row0_col1" class="data row0 col1" >2064.6237</td>
#       <td id="T_c9a80_row0_col2" class="data row0 col2" >15626214.7794</td>
#       <td id="T_c9a80_row0_col3" class="data row0 col3" >3953.0007</td>
#       <td id="T_c9a80_row0_col4" class="data row0 col4" >0.8934</td>
#       <td id="T_c9a80_row0_col5" class="data row0 col5" >0.3542</td>
#       <td id="T_c9a80_row0_col6" class="data row0 col6" >0.2291</td>
#     </tr>
#   </tbody>
# </table>
#    age     sex        bmi  children smoker     region       charges  \
# 0   19  female  27.900000         0    yes  southwest  16884.923828
# 1   18    male  33.770000         1     no  southeast   1725.552246
# 2   28    male  33.000000         3     no  southeast   4449.461914
# 3   33    male  22.705000         0     no  northwest  21984.470703
# 4   32    male  28.879999         0     no  northwest   3866.855225
#
#    prediction_label
# 0      18817.243290
# 1       3793.138245
# 2       6339.621482
# 3      11049.333537
# 4       3580.806127

# %%
save_model(best, 'my_best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=/var/folders/jx/rdhgw4n94cvb3tl_p0k9_4br0000gn/T/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['age', 'bmi', 'children'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['sex', 'smoker', 'region'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   T...
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': female    0
#  male      1
#  NaN      -1
#  dtype: int64},
#                                                                          {'col': 'smoker',
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': no     0
#  yes    1
#  NaN   -1
#  dtype: int64}]))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['region'],
#                                      transformer=OneHotEncoder(cols=['region'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('trained_model',
#                   GradientBoostingRegressor(random_state=6479))]),
#  'my_best_pipeline.pkl')

# %% [markdown]
# ## Clustering

# %%
from pycaret.datasets import get_data
data = get_data('jewellery')
# Out:
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %%
from pycaret.clustering import *
s = setup(data, normalize = True)
# Out:
# <style type="text/css">
# #T_90123_row4_col1, #T_90123_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_90123">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90123_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_90123_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90123_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90123_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_90123_row0_col1" class="data row0 col1" >634</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90123_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_90123_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90123_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_90123_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90123_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_90123_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90123_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_90123_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90123_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_90123_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_90123_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_90123_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_90123_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_90123_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_90123_row8_col0" class="data row8 col0" >Normalize</td>
#       <td id="T_90123_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_90123_row9_col0" class="data row9 col0" >Normalize method</td>
#       <td id="T_90123_row9_col1" class="data row9 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_90123_row10_col0" class="data row10 col0" >CPU Jobs</td>
#       <td id="T_90123_row10_col1" class="data row10 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_90123_row11_col0" class="data row11 col0" >Use GPU</td>
#       <td id="T_90123_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_90123_row12_col0" class="data row12 col0" >Log Experiment</td>
#       <td id="T_90123_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_90123_row13_col0" class="data row13 col0" >Experiment Name</td>
#       <td id="T_90123_row13_col1" class="data row13 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_90123_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_90123_row14_col0" class="data row14 col0" >USI</td>
#       <td id="T_90123_row14_col1" class="data row14 col1" >ffe0</td>
#     </tr>
#   </tbody>
# </table>

# %%
kmeans = create_model('kmeans')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            08:12:24
# Status     . . . . . . . . . . . . . . . . . .  Fitting 4 Clusters
# Estimator  . . . . . . . . . . . . . . . . . .  K-Means Clustering
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
print(kmeans)

# %%
evaluate_model(kmeans)

# %%
plot_model(kmeans, plot = 'elbow')

# %%
plot_model(kmeans, plot = 'silhouette')

# %%
result = assign_model(kmeans)
result.head()

# %%
predictions = predict_model(kmeans, data = data)
predictions.head()

# %%
save_model(kmeans, 'kmeans_pipeline')

# %%
loaded_model = load_model('kmeans_pipeline')
print(loaded_model)

# %% [markdown]
# ## Anomaly Detection

# %%
from pycaret.datasets import get_data
data = get_data('anomaly')
# Out:
#        Col1      Col2      Col3      Col4      Col5      Col6      Col7  \
# 0  0.263995  0.764929  0.138424  0.935242  0.605867  0.518790  0.912225
# 1  0.546092  0.653975  0.065575  0.227772  0.845269  0.837066  0.272379
# 2  0.336714  0.538842  0.192801  0.553563  0.074515  0.332993  0.365792
# 3  0.092108  0.995017  0.014465  0.176371  0.241530  0.514724  0.562208
# 4  0.325261  0.805968  0.957033  0.331665  0.307923  0.355315  0.501899
#
#        Col8      Col9     Col10
# 0  0.608234  0.723782  0.733591
# 1  0.331679  0.429297  0.367422
# 2  0.861309  0.899017  0.088600
# 3  0.158963  0.073715  0.208463
# 4  0.558449  0.885169  0.182754

# %%
from pycaret.anomaly import *
s = setup(data)
# Out:
# <style type="text/css">
# #T_76a0a_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_76a0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76a0a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_76a0a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76a0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76a0a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_76a0a_row0_col1" class="data row0 col1" >6789</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_76a0a_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_76a0a_row1_col1" class="data row1 col1" >(1000, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_76a0a_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_76a0a_row2_col1" class="data row2 col1" >(1000, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_76a0a_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_76a0a_row3_col1" class="data row3 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_76a0a_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_76a0a_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_76a0a_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_76a0a_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_76a0a_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_76a0a_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_76a0a_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_76a0a_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_76a0a_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_76a0a_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_76a0a_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_76a0a_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_76a0a_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_76a0a_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_76a0a_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_76a0a_row11_col1" class="data row11 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_76a0a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_76a0a_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_76a0a_row12_col1" class="data row12 col1" >851c</td>
#     </tr>
#   </tbody>
# </table>

# %%
iforest = create_model('iforest')
print(iforest)
# Out:
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# IForest(behaviour='new', bootstrap=False, contamination=0.05,
#     max_features=1.0, max_samples='auto', n_estimators=100, n_jobs=-1,
#     random_state=6789, verbose=0)

# %%
models()
# Out:
#                                         Name                    Reference
# ID
# abod            Angle-base Outlier Detection        pyod.models.abod.ABOD
# cluster       Clustering-Based Local Outlier      pyod.models.cblof.CBLOF
# cof         Connectivity-Based Local Outlier          pyod.models.cof.COF
# iforest                     Isolation Forest  pyod.models.iforest.IForest
# histogram  Histogram-based Outlier Detection        pyod.models.hbos.HBOS
# knn             K-Nearest Neighbors Detector          pyod.models.knn.KNN
# lof                     Local Outlier Factor          pyod.models.lof.LOF
# svm                   One-class SVM detector      pyod.models.ocsvm.OCSVM
# pca             Principal Component Analysis          pyod.models.pca.PCA
# mcd           Minimum Covariance Determinant          pyod.models.mcd.MCD
# sod               Subspace Outlier Detection          pyod.models.sod.SOD
# sos             Stochastic Outlier Selection          pyod.models.sos.SOS

# %%
# kernel die
plot_model(iforest, plot = 'tsne')

# %%
plot_model(iforest, plot = 'umap')

# %%
result = assign_model(iforest)
result.head()
# Out:
#        Col1      Col2      Col3      Col4      Col5      Col6      Col7  \
# 0  0.263995  0.764929  0.138424  0.935242  0.605867  0.518790  0.912225
# 1  0.546092  0.653975  0.065575  0.227772  0.845269  0.837066  0.272379
# 2  0.336714  0.538842  0.192801  0.553563  0.074515  0.332993  0.365792
# 3  0.092108  0.995017  0.014465  0.176371  0.241530  0.514724  0.562208
# 4  0.325261  0.805968  0.957033  0.331665  0.307923  0.355315  0.501899
#
#        Col8      Col9     Col10  Anomaly  Anomaly_Score
# 0  0.608234  0.723782  0.733591        0      -0.022957
# 1  0.331679  0.429297  0.367422        0      -0.074388
# 2  0.861309  0.899017  0.088600        1       0.022341
# 3  0.158963  0.073715  0.208463        1       0.026761
# 4  0.558449  0.885169  0.182754        0      -0.017163

# %%
predictions = predict_model(iforest, data = data)
predictions.head()
# Out:
#        Col1      Col2      Col3      Col4      Col5      Col6      Col7  \
# 0  0.263995  0.764929  0.138424  0.935242  0.605867  0.518790  0.912225
# 1  0.546092  0.653975  0.065575  0.227772  0.845269  0.837066  0.272379
# 2  0.336714  0.538842  0.192801  0.553563  0.074515  0.332993  0.365792
# 3  0.092108  0.995017  0.014465  0.176371  0.241530  0.514724  0.562208
# 4  0.325261  0.805968  0.957033  0.331665  0.307923  0.355315  0.501899
#
#        Col8      Col9     Col10  Anomaly  Anomaly_Score
# 0  0.608234  0.723782  0.733591        0      -0.022957
# 1  0.331679  0.429297  0.367422        0      -0.074388
# 2  0.861309  0.899017  0.088600        1       0.022341
# 3  0.158963  0.073715  0.208463        1       0.026761
# 4  0.558449  0.885169  0.182754        0      -0.017163

# %%
save_model(iforest, 'iforest_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=/var/folders/jx/rdhgw4n94cvb3tl_p0k9_4br0000gn/T/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['Col1', 'Col2', 'Col3', 'Col4',
#                                               'Col5', 'Col6', 'Col7', 'Col8',
#                                               'Col9', 'Col10'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('trained_model',
#                   IForest(behaviour='new', bootstrap=False, contamination=0.05,
#      max_features=1.0, max_samples='auto', n_estimators=100, n_jobs=-1,
#      random_state=6789, verbose=0))]),
#  'iforest_pipeline.pkl')

# %%
loaded_model = load_model('iforest_pipeline')
print(loaded_model)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=Memory(location=/var/folders/jx/rdhgw4n94cvb3tl_p0k9_4br0000gn/T/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['Col1', 'Col2', 'Col3', 'Col4',
#                                              'Col5', 'Col6', 'Col7', 'Col8',
#                                              'Col9', 'Col10'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=[],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('trained_model',
#                  IForest(behaviour='new', bootstrap=False, contamination=0.05,
#     max_features=1.0, max_samples='auto', n_estimators=100, n_jobs=-1,
#     random_state=6789, verbose=0))])

# %% [markdown]
# ## Natural Language Processing

# %%
# load dataset
from pycaret.datasets import get_data
data = get_data('kiva')
# Out:
#               country                                                 en  \
# 0  Dominican Republic  "Banco Esperanza" is a group of 10 women looki...
# 1  Dominican Republic  "Caminemos Hacia Adelante" or "Walking Forward...
# 2  Dominican Republic  "Creciendo Por La Union" is a group of 10 peop...
# 3  Dominican Republic  "Cristo Vive" ("Christ lives" is a group of 10...
# 4  Dominican Republic  "Cristo Vive" is a large group of 35 people, 2...
#
#   gender  loan_amount nonpayment    sector  status
# 0      F         1225    partner    Retail       0
# 1      F         1975     lender  Clothing       0
# 2      F         2175    partner  Clothing       0
# 3      F         1425    partner  Clothing       0
# 4      F         4025    partner      Food       0

# %%
# print first document
print(data['en'][0])
# Out:
# "Banco Esperanza" is a group of 10 women looking to receive a small loan. Each of them has taken out a very small loan already, so this would be their second. With this loan the group is going to try and expand their small businesses and start generating more income. <P>
#
# Eduviges is the group representative and leader of the group. Eduviges has a lot on the line because she has 6 children that she has to take care of. She told me that those children are the reason she wants to be successful. She wants to be able to provide a different life for them and show them that they can be successful as well. <P>
#
# Eduviges has a very small business selling shoes and Avon products. She plans to expand using this loan and dreams of success. The whole group is ready for this new challenge and are on the road to bettering their lives. On behalf of Eduviges, the group, and Esperanza International--------- Thank you for your support!!!!

# %%
# init setup
from pycaret.nlp import *
s = setup(data, target = 'en')
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (Type Error): spacy english model is not yet downloaded. See the documentation of setup to see installation guide.

# %%
models()
# Out:
#                                   Name                  Reference
# ID
# lda        Latent Dirichlet Allocation     gensim/models/ldamodel
# lsi           Latent Semantic Indexing     gensim/models/lsimodel
# hdp     Hierarchical Dirichlet Process     gensim/models/hdpmodel
# rp                  Random Projections      gensim/models/rpmodel
# nmf  Non-Negative Matrix Factorization  sklearn.decomposition.NMF

# %%
lda = create_model('lda')
print(lda)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 lda = create_model('lda')
#       2 print(lda)
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pycaret/nlp/__init__.py:1194, in create_model(model, multi_core, num_topics, verbose, system, experiment_custom_tags, **kwargs)
#    1186 monitor = pd.DataFrame(
#    1187     [
#    1188         ["Initiated", ". . . . . . . . . . . . . . . . . .", timestampStr],
#    (...)
#    1191     columns=["", " ", "  "],
#    1192 ).set_index("")
#    1193 if verbose:
# -> 1194     if html_param:
#    1195         display(progress)
#    1196         display(monitor, display_id="monitor")
#
# NameError: name 'html_param' is not defined

# %%
plot_model(lda, plot = 'frequency')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plot_model(lda, plot = 'frequency')
#
# NameError: name 'lda' is not defined

# %%
evaluate_model(lda)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 evaluate_model(lda)
#
# NameError: name 'lda' is not defined

# %%
lda_results = assign_model(lda)
lda_results.head()

# %% [markdown]
# ## Associations Rules Mining

# %%
from pycaret.datasets import get_data
data = get_data('france')
# Out:
#   InvoiceNo StockCode                      Description  Quantity  \
# 0    536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 1    536370     22727        ALARM CLOCK BAKELIKE RED         24
# 2    536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 3    536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 4    536370     21883                 STARS GIFT TAPE         24
#
#       InvoiceDate  UnitPrice  CustomerID Country
# 0  12/1/2010 8:45       3.75     12583.0  France
# 1  12/1/2010 8:45       3.75     12583.0  France
# 2  12/1/2010 8:45       3.75     12583.0  France
# 3  12/1/2010 8:45       0.85     12583.0  France
# 4  12/1/2010 8:45       0.65     12583.0  France

# %%
from pycaret.arules import * 
arules = setup(data, transaction_id = 'InvoiceNo', item_id = 'Description')
# Out:
# <style type="text/css">
# </style>
# <table id="T_415d5">
#   <thead>
#     <tr>
#       <th id="T_415d5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_415d5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_415d5_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_415d5_row0_col1" class="data row0 col1" >359</td>
#     </tr>
#     <tr>
#       <td id="T_415d5_row1_col0" class="data row1 col0" ># Transactions</td>
#       <td id="T_415d5_row1_col1" class="data row1 col1" >461</td>
#     </tr>
#     <tr>
#       <td id="T_415d5_row2_col0" class="data row2 col0" ># Items</td>
#       <td id="T_415d5_row2_col1" class="data row2 col1" >1565</td>
#     </tr>
#     <tr>
#       <td id="T_415d5_row3_col0" class="data row3 col0" >Ignore Items</td>
#       <td id="T_415d5_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#   </tbody>
# </table>

# %%
create_model(metric = 'confidence', threshold = 0.3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 create_model(metric = 'confidence', threshold = 0.3)
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pycaret/arules/__init__.py:203, in create_model(metric, threshold, min_support, round, low_memory, max_len)
#     200 import pandas as pd
#     201 from IPython.display import HTML, clear_output, display, update_display
# --> 203 _check_soft_dependencies("mlxtend", extra="models", severity="error")
#     204 from mlxtend.frequent_patterns import apriori, association_rules
#     206 # reshaping the dataframe
#
# File ~/opt/anaconda3/envs/ML/lib/python3.8/site-packages/pycaret/utils/_dependencies.py:152, in _check_soft_dependencies(package, severity, extra, install_name)
#     150 if severity == "error":
#     151     logger.exception(f"{msg}")
# --> 152     raise ModuleNotFoundError(msg)
#     153 elif severity == "warning":
#     154     logger.warning(f"{msg}")
#
# ModuleNotFoundError:
# 'mlxtend' is a soft dependency and not included in the pycaret installation. Please run: `pip install mlxtend` to install.
# Alternately, you can install this by running `pip install pycaret[models]`

# %%
plot_model(model, plot = '3d')
